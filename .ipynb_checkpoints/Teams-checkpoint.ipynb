# %%
import pandas as pd

# %%
df = pd.read_csv('all_seasons.csv')
df
# Out:
#        Unnamed: 0        player_name team_abbreviation   age  player_height  \
# 0               0      Dennis Rodman               CHI  36.0         198.12
# 1               1  Dwayne Schintzius               LAC  28.0         215.90
# 2               2       Earl Cureton               TOR  39.0         205.74
# 3               3        Ed O'Bannon               DAL  24.0         203.20
# 4               4        Ed Pinckney               MIA  34.0         205.74
# ...           ...                ...               ...   ...            ...
# 12300       12300    Markieff Morris               MIA  32.0         205.74
# 12301       12301     Markelle Fultz               ORL  24.0         193.04
# 12302       12302       Marcus Smart               BOS  28.0         193.04
# 12303       12303     Marcus Garrett               MIA  23.0         195.58
# 12304       12304       Micah Potter               DET  24.0         208.28
#
# ...

# %%
dennis_rodman_team = list(set(df[df['player_name'] == "Shaquille O'Neal"]['team_abbreviation']))
dennis_rodman_team
# Out:
# ['LAL', 'PHX', 'BOS', 'CLE', 'MIA']

# %%
boston_players = list(set(df[df['team_abbreviation'] == "BOS"]['player_name']))
#len(boston_players)
sorted(boston_players)
# Out:
# ['Aaron Nesmith',
#  'Abdel Nader',
#  'Adrian Griffin',
#  'Al Horford',
#  'Al Jefferson',
#  'Allan Ray',
#  'Alton Lister',
#  'Amir Johnson',
#  'Andrew DeClercq',
#  'Antoine Walker',
#  'Aron Baynes',
#  'Avery Bradley',
#  'Bimbo Coles',
#  'Brad Wanamaker',
#  'Brandon Bass',
#  'Brandon Hunter',
#  'Brett Szabo',
#  'Brian Scalabrine',
#  'Brodric Thomas',
#  'Bruce Bowen',
#  'Bruno Sundov',
#  'Bryant Stith',
#  'CJ Miles',
#  'Calbert Cheaney',
#  'Carlos Arroyo',
#  'Carsen Edwards',
#  'Chris Babb',
#  'Chris Carr',
#  'Chris Herren',
#  'Chris Johnson',
#  'Chris Mihm',
#  'Chris Wilcox',
#  'Chucky Atkins',
#  'Coty Clarke',
#  'Courtney Lee',
#  'DJ White',
#  'Damon Jones',
#  'Dan Dickau',
#  'Dana Barros',
#  'Daniel Theis',
#  'Danny Fortson',
#  'Darko Milicic',
#  'David Wesley',
#  'Dee Brown',
#  'Delonte West',
#  'Demetrius Jackson',
#  'Derrick White',
#  'Dino Radja',
#  "Dontae' Jones",
#  'Doug Overton',
#  'Dwayne Jones',
#  'Dwayne Schintzius',
# ...

# %%
shaq = set(df[df['player_name'] == "Shaquille O'Neal"]['team_abbreviation'])
print(shaq)
tatum  = set(df[df['player_name'] == "Jayson Tatum"]['team_abbreviation'])
print(tatum)
# Out:
# {'LAL', 'PHX', 'BOS', 'CLE', 'MIA'}
# {'BOS'}

# %%
#name1 = input('Introduce el nombre:  ')
#name2 = input('Introduce el nombre:  ')

shaq = set(df[df['player_name'] == "Shaquille O'Neal"]['team_abbreviation'])
print(shaq)
tatum  = set(df[df['player_name'] == "Jayson Tatum"]['team_abbreviation'])
print(tatum)
equipos_comunes = shaq & tatum

# Verificar si hay elementos comunes
if equipos_comunes:
    print("Hay elementos comunes entre ambos conjuntos:", equipos_comunes)
else:
    print("No hay elementos comunes entre ambos conjuntos.")
# Out:
# {'LAL', 'PHX', 'BOS', 'CLE', 'MIA'}
# {'BOS'}
# Hay elementos comunes entre ambos conjuntos: {'BOS'}

# %%
name1 = input('Introduce el nombre:  ')
name2 = input('Introduce el nombre:  ')

shaq = set(df[df['player_name'] == name1]['team_abbreviation'])
tatum  = set(df[df['player_name'] == name2]['team_abbreviation'])

equipos_comunes = shaq & tatum

# Verificar si hay elementos comunes
if equipos_comunes:
    print("Hay elementos comunes entre ambos conjuntos:", equipos_comunes)
else:
    print("No hay elementos comunes entre ambos conjuntos.")
# Out:
# Introduce el nombre:  tatum
# Introduce el nombre:  o'neal
# No hay elementos comunes entre ambos conjuntos.

# %%
name = input('Introduce el nombre:  ')

first_r = ['BOS', 'CLE', 'PHX']
second_r = ['LAL', 'MIA', 'OKC']

teams = set(df[df['player_name'] == name]['team_abbreviation'])


for team in teams:
    if first_r[0] in teams and second_r[2] in teams:
        print('correcto')
        break
    else:
        print('incorrecto')
        break
    #if df['player_name']['team_abbreviation'] in team and df['player_name']['team_abbreviation'] in team:
 #   print(f'{primer_valor} and {segundo_valor}')
# Out:
# Introduce el nombre:  Shaquille O'Neal
# incorrecto

# %%
Shaquille O'Neal

# %%
import random
equipos = ['ATL', 'BKN', 'BOS', 'CHA', 'CHH', 'CHI', 'CLE', 'DAL', 'DEN', 'DET', 'GSW', 'HOU', 'IND', 'LAC', 'LAL', 'MEM', 'MIA', 'MIL', 
 'MIN', 'NJN', 'NOH', 'NOK', 'NOP', 'NYK', 'OKC', 'ORL', 'PHI', 'PHX', 'POR', 'SAC', 'SAS', 'SEA', 'TOR', 'UTA', 'VAN', 'WAS']
#equipos = ['ATL', 'BKN', 'BOS', 'CHA', 'CHI', 'CLE', 'DAL', 'DEN', 'DET', 'GSW', 'HOU', 'IND', 'LAC', 'LAL', 'MEM', 'MIA', 'MIL', 
 #'MIN', 'NJN', 'NOP', 'NYK', 'OKC', 'ORL', 'PHI', 'PHX', 'POR', 'SAC', 'SAS', 'TOR', 'UTA', 'WAS']

first_r = []
second_r = []
# CREC QUE POT TORNAR MATEIX NOMBRE 2 VEGADES, REPASSA    
rands = [random.randint(0, 36) for i in range(6) ] # if i not in rands SI FAIG ASO DARRERA, ME TORNA UN DE BUIT, FER FUNCIÓ
count = 0
for i in rands:
    count += 1
    if count <= 3:
        first_r.append(equipos[i])
    else:
        second_r.append(equipos[i])
print(first_r)
print(second_r)

name = input('Introduce el nombre del jugador:  ')
teams = set(df[df['player_name'] == name.title()]['team_abbreviation'])

num1 = int(input('Introduce un número: '))
num2 = int(input('Introduce un número: '))
for team in teams:
    
    if first_r[num1] in teams and second_r[num2] in teams:
        print('correcto')
        break
    else:
        print('incorrecto')
        break
# Out:
# ['SAC', 'SAC', 'NOK']
# ['PHX', 'PHX', 'PHX']
# Introduce el nombre del jugador:  devin booker
# Devin Booker

# %%
player = list(set(df[df['player_name'] == "Shaquille O'Neal"]['team_abbreviation']))
player
# Out:
# ['BOS']

# %%
# FALLA PERQUÈ TENC UN SET I NO UNA LLISTA CREC
import random
equipos = ['ATL', 'BKN', 'BOS', 'CHA', 'CHH', 'CHI', 'CLE', 'DAL', 'DEN', 'DET', 'GSW', 'HOU', 'IND', 'LAC', 'LAL', 'MEM', 'MIA', 'MIL', 
 'MIN', 'NJN', 'NOH', 'NOK', 'NOP', 'NYK', 'OKC', 'ORL', 'PHI', 'PHX', 'POR', 'SAC', 'SAS', 'SEA', 'TOR', 'UTA', 'VAN', 'WAS']
#equipos = ['ATL', 'BKN', 'BOS', 'CHA', 'CHI', 'CLE', 'DAL', 'DEN', 'DET', 'GSW', 'HOU', 'IND', 'LAC', 'LAL', 'MEM', 'MIA', 'MIL', 
# 'MIN', 'NJN', 'NOP', 'NYK', 'OKC', 'ORL', 'PHI', 'PHX', 'POR', 'SAC', 'SAS', 'TOR', 'UTA', 'WAS']

first_r = []
second_r = []
rands = set()
while len(rands) < 6:
    rands.add(random.randint(0, 36))

# Si hay algún número repetido, generamos un reemplazo adicional
while len(rands) < 6:
    rands.add(random.randint(0, 36))


count = 0
for i in list(rands):
    count += 1
    if count <= 3:
        first_r.append(equipos[i])
    else:
        second_r.append(equipos[i])
print(first_r)
print(second_r)

name = input('Introduce el nombre del jugador:  ')

teams = set(df[df['player_name'] == name]['team_abbreviation'])

num1 = int(input('Introduce un número: '))
num2 = int(input('Introduce un número: '))
for team in teams:
    if first_r[num1] in teams and second_r[num2] in teams:
        print('correcto')
        break
    else:
        print('incorrecto')
        break
# Out:
# ['HOU', 'IND', 'MEM']
# ['MIA', 'MIN', 'NOH']
# Introduce el nombre del jugador:  kyle lowry
# Introduce un número: 0
# Introduce un número: 1
